# %%
## All your base


import re

##formating a line of text into a list

inputfile = "allyourbasepractice.txt"

##\n is new line
##anything after \n should be in an array/list

def textformatter(inputtextfile):
    input = open(inputtextfile, "r")
    inputlist = []
    for line in input:
        inputlist.append(line)

    iterlist = {} 
    itercount = 0
    for item in inputlist:
        item = item.rstrip("\n")
        iterlist[itercount]= item
        itercount = itercount +1
    return iterlist

casedic = textformatter(inputfile)



##finding unique letters to convert to base
for k,v in casedic.items():
    ## create list of char from string
    listofletters = list(v)
    ## find unique letters by creating set
    uniqueletters = set(listofletters)
    ## find the index of the list by finding length of list and subtracting 1
    totalindex = len(listofletters) - 1
    ## because base is never unary, add 1 to base 1 if occurs. 
    ## number will always start with 1 and will therefore be minimized
    base = len(uniqueletters)
    if base == 1:
        base = base + 1
    print(uniqueletters)
    print(totalindex)
    print(base)
    ##create new list for every list of number, start with 1,0,2,etc
    try:
        print(int(v,base))
    except ValueError:
        if len(v) > 1:
            if totalindex + 1 >= 10:
                numlist = range(10)
                numlistcont = []
                x = 10
                y = 0
                while x < totalindex + 1:
                    numlistcont.append(y)
                    x = x + 1
                    y=y+1
                numlist.append(numlistcont)
                numlist[1], numlist[0] = numlist[0], numlist[1] 
                newnumasstring = "".join(str(x) for x in numlist)
                print(v)
                print(newnumasstring)
        else:
            print(1)
    

                

        
#####  still working. not done yet
# Out:
# set(['1', '0'])
# 2
# 2
# 4
# set(['1', '0'])
# 7
# 2
# 201
# set(['a', 's', 'c', 't'])
# 3
# 4
# set(['i', 'z', 'g'])
# 2
# 3
# set(['a', 'e', 'h', 'o', 'r', 'u', 'w', 'y'])
# 8
# 8
# set(['e', 'g', 'm', 'l', 'n', 't'])
# 8
# 6
# set(['a', 'l', 'o', 'r', 'u', 'y'])
# 6
# 6
# set(['a', 'r', 's', 'b', 'e'])
# 6
# 5
# set(['b', 'e', 'g', 'l', 'o', 'n', 't'])
# 7
# 7
# set(['s', 'u'])
# 1
# 2
# set(['a', 'h'])
# 5
# 2
# set(['1', '0', '3', '2', '5', '4', '7', '6', '8'])
# 8
# 9
# 44317196
# set(['1'])
# 8
# 2
# 511
# set(['z'])
# 0
# 2
# 1
# set(['a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h'])
# 8
# 9
# set(['1', '0', '3', '2', '5', '4', '7', '6', '9', '8'])
# 9
# 10
# 1023456789
# set(['a', 'c', 'b', 'e', 'd', 'g', 'f', 'i', 'h', 'k', 'j', 'm', 'l', 'o', 'n'])
# 14
# 15
# abcdefghijklmno
# 1023456789[0, 1, 2, 3, 4]
# set(['q', 'p', 's', 'r', 'u', 't', 'w', 'v', 'y', 'x', 'z'])
# 10
# 11
# pqrstuvwxyz
# 1023456789[0]
# set(['a', 'c', 'b', 'i', 'k', 'm', 'o', 'n', 's', 'w', 'y'])
# 13
# ...
